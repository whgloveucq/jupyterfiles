# %%
import tushare  as ts
import pandas as pd
import matplotlib.pyplot as plt  
import mplfinance as mpf
# https://akshare.akfamily.xyz/tutorial.html （有时间研究下和tushare类似的akshare）
# https://www.heywhale.com/register_landing

# %%
#显示所有列
pd.set_option('display.max_columns', 100)
#显示所有行
pd.set_option('display.max_rows', 100)

# %%
#统一数据来源
def get_source():
    pro = ts.pro_api('5fb9551d1e4c7339259b68703d554c50dd7cebc016fcfc8dd11fd438')
    return pro
#股票列表
def get_data():
    df = get_source().stock_basic()
    return df
#获取股票名称
def get_stock_name(df1,df2):
#     name=df.query("ts_code=='{}'".format(df['ts_code']))['name'][0]
    for ts_code in df1['ts_code']:
        for ts_code2 in df2['ts_code']:
            if  ts_code==ts_code2: 
                 return df2[df2['ts_code']==ts_code2]['name']
#交易日历
def get_cal():
        df_cal=get_source().trade_cal()
        return df_cal
#
#获取沪股通成分,hs_type:SH,SZ
def stock_kind(kind):
        df_type = get_source().hs_const(hs_type=kind) 
        return  df_type
#上市公司基本信息  交易所代码 ，exchange_name-SSE上交所 SZSE深交所
def company_info(exchange_name,ts_codes):
    df_company =get_source().stock_company(exchange=exchange_name,ts_code=ts_codes, fields='ts_code,chairman,manager,secretary,reg_capital,setup_date,province,city,introduction,website,employees,main_business,business_scope')
    return df_company
#上市公司管理层
def company_managers(ts_code,ann_date,start_date,end_date):
        df_managers= get_source().stk_managers(ts_code=ts_code,ann_date=ann_date,start_date=start_date,end_date=end_date)
        return  df_managers
#管理层持股数
def manager_stocks(ts_code,end_date):
        df_stocks= get_source().stk_rewards(ts_code=ts_code,end_date=end_date)
        return  df_stocks
#IPO新股
def new_stocks(start_date,end_date):
        df_news= get_source().new_share(start_date=start_date, end_date=end_date)
        return  df_news
#股票的换手率问题
#某日换手率前n名的股票 ，或某阶段换手率前n名的股票
def turnover_n(trade_date,n):
    turnover_n=get_source().daily_basic(trade_date=trade_date).sort_values(by='turnover_rate',ascending=False).ts_code.tolist()[:n]
    return turnover_n
#股票的成交额问题。
def amount_n(trade_date,n):
        amount_n=get_source().daily(trade_date=trade_date).sort_values(by='amount',ascending=False).ts_code.tolist()[:n]
        return amount_n
#换手率和成交额的交集
def amount_turnover(trade_date,n):
     return list(set(amount_n(trade_date,n))&set(turnover_n(trade_date,n)))
#备用列表
def get_bakdata(trade_date):
    bak_data=get_source().bak_basic(trade_date=trade_date, fields='trade_date,ts_code,name,industry,pe')
    return bak_data
##获取日线行情
def stock_daily(ts_code,start_date,end_date): 
    if ts_code=='NA':
        df=get_source().daily(trade_date=start_date)
    else:
        df=get_source().daily(ts_code=ts_code, start_date=start_date, end_date=end_date)
    return df
##获取周线行情
def stock_weekly(ts_code,start_date,end_date):
    if ts_code=='NA':
        df=get_source().weekly(trade_date=start_date)
    else:
        df=get_source().weekly(ts_code=ts_code, start_date=start_date, end_date=end_date)
    return df
##获取月线行情

##寻找股票的
# condition = (stock_collection['close']-stock_collection['open'])/stock_collection['open']>0.03
def stock_condition(stock_collection,condition):
    return stock_collection.loc[condition]


#获取历史行情数据

#股票池细化。

#股票列表数据

# %%
##股票财务数据
fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps,diluted_eps,total_revenue'
df_stocks_finance=get_source().income(ts_code='600000.SH', start_date='20230101', end_date='20230515')
##资产负债表数据
fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,cap_rese'
df_stocks_balance_sheet=get_source().balancesheet(ts_code='600000.SH', start_date='20230101', end_date='20230515')
##现金流量表
df_cashflow =get_source().cashflow(ts_code='600000.SH', start_date='20180101', end_date='20180730')

##业绩快报
df_express=get_source().express(ts_code='600000.SH', start_date='20180101', end_date='20180701', fields='ts_code,ann_date,end_date,revenue,operate_profit,total_profit,n_income,total_assets')
# df_express_vip=get_source().express_vip(period='20221231',fields='ts_code,ann_date,end_date,revenue,operate_profit,total_profit,n_income,total_assets')

# %%
#基本状况、财务指标状况、行业市场声誉和市场潜力、公司声誉和公司潜力，公司人员状况、领导能力。
df_stocks=get_data()
# 1、需求超过三年的上市公司股票列表
df_stocks_age_gt3=df_stocks.query('list_date <"20210101"')

# df_stocks.query("ts_code.str.contains('002329.SZ|688271.SH|002514.SZ|688041.SH|688016.SH|002197.SZ')",engine="python")
#20221207
# 比如“ROE连续5年大于20%”“近两年营收增长率大于10%”“近两年净利润增长率大于10%”“上市时间大于3年”等
df_stocks_age_gt3['industry']=df_stocks_age_gt3['industry'].apply(str)
##选定超过三年的行业股票
df_stocks_age_gt3_base=df_stocks_age_gt3.query("industry.str.contains('医药|互联网|新能源|材料|高端|消费')",engine="python")[['ts_code','name','industry']]
#如何获取ROE
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9544\1760678146.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stocks_age_gt3['industry']=df_stocks_age_gt3['industry'].apply(str)

# %%
import time
from time import mktime
from dateutil.relativedelta import relativedelta
from datetime import datetime,timedelta

#根据这些股票，加上日期，ROE,换手率、成交额等信息。
# df_stocks_age_gt3_base.head(1000)
#日行情信息 及晒选。
trdate=(datetime.today().date() - timedelta(days=2)).strftime('%Y%m%d')
# trdate='20230524'
#交易日期所在周
# trdate_week=

stock_collection=stock_daily('NA',trdate,'')
condition = (stock_collection['close']-stock_collection['open'])/stock_collection['open']>0.03
df_selected=stock_condition(stock_collection,condition)
#股票信息
colname=['ts_code','name','industry','trade_date','open','high','low','close','pre_close','change','pct_chg']
df_selected_tmp1=pd.merge(df_selected,df_stocks_age_gt3_base,on=["ts_code"],how='inner')[colname]
#加上换手率 、市赢率、市盈率TTM、市净率
df_index_daily = get_source().index_dailybasic(trade_date=trdate
#                                                ,fields='ts_code,trade_date,turnover_rate,pe'
                                              )
colname.extend(['turnover_rate','turnover_rate_f','pe','pe_ttm','pb'])  

df_selected_tmp2=pd.merge(df_selected_tmp1,df_index_daily,on=["ts_code","trade_date"],how='left')[colname]
#加上成交额
#加上 ROE

# %%
get_source().index_dailybasic(ts_code='000001.SH')
# Out:
#         ts_code trade_date      total_mv      float_mv   total_share
# 0     000001.SH   20230601  5.645523e+13  4.226141e+13  5.578409e+12  \
# 1     000001.SH   20230531  5.639071e+13  4.224614e+13  5.577055e+12
# 2     000001.SH   20230530  5.676939e+13  4.253483e+13  5.576719e+12
# 3     000001.SH   20230529  5.669958e+13  4.249717e+13  5.576260e+12
# 4     000001.SH   20230526  5.643223e+13  4.231748e+13  5.573443e+12
# ...         ...        ...           ...           ...           ...
# 2995  000001.SH   20110201  2.182107e+13  1.439662e+13  2.819156e+12
# 2996  000001.SH   20110131  2.174897e+13  1.426147e+13  2.818936e+12
# 2997  000001.SH   20110128  2.143960e+13  1.407930e+13  2.818895e+12
# 2998  000001.SH   20110127  2.143539e+13  1.406005e+13  2.818818e+12
# 2999  000001.SH   20110126  2.105830e+13  1.385579e+13  2.817813e+12
#
#        float_share    free_share  turnover_rate  turnover_rate_f       pe
# 0     4.239805e+12  1.778285e+12         0.7000           1.6800  13.2100  \
# 1     4.238347e+12  1.775989e+12         0.6600           1.5800  13.2000
# 2     4.238162e+12  1.775958e+12         0.6900           1.6400  13.2800
# 3     4.237776e+12  1.775776e+12         0.6800           1.6100  13.2700
# 4     4.235931e+12  1.774494e+12         0.5900           1.4100  13.2000
# ...            ...           ...            ...              ...      ...
# 2995  1.614750e+12  5.409495e+11         0.4491           1.3406  21.3606
# 2996  1.607090e+12  5.408965e+11         0.5649           1.6783  21.2945
# 2997  1.606909e+12  5.408958e+11         0.5252           1.5603  21.0178
# 2998  1.606669e+12  5.406556e+11         0.6538           1.9430  21.0156
# 2999  1.606585e+12  5.405712e+11         0.3761           1.1179  20.6842
#
#        pe_ttm      pb
# 0     13.0800  1.3000
# 1     13.0700  1.3000
# 2     13.1600  1.3100
# 3     13.1400  1.3100
# 4     13.0800  1.3000
# ...       ...     ...
# 2995  16.6534  2.4026
# 2996  16.6145  2.3961
# 2997  16.3990  2.3601
# 2998  16.3943  2.3602
# 2999  16.1307  2.3221
#
# [3000 rows x 12 columns]

# %%
# df_selected_tmp1.query("industry.str.contains( '互联网')").head(100)
# df_index_daily.head(100)
df_selected_tmp2.head(100).query("open<=10")
# get_source().weekly(trade_date='20230519')

# df_index_daily.query("ts_code=='003010.SZ'")
# 000001.SH
# stock_collection.head(10)
# stock_collection.query("ts_code=='000001.SH'")
# df_index_daily.query("ts_code=='000001.SH'")
# Out:
#       ts_code  name industry trade_date  open  high   low  close  pre_close
# 1   603716.SH  塞力医疗     医药商业   20230620  9.66  9.97  9.63   9.97       9.67  \
# 7   600892.SH  大晟文化      互联网   20230620  6.07  6.73  6.06   6.73       6.12
# 9   002788.SZ  鹭燕医药     医药商业   20230620  9.08  9.47  9.06   9.47       9.08
# 11  002168.SZ  惠程科技      互联网   20230620  5.04  5.20  5.04   5.20       4.73
# 12  300043.SZ  星辉娱乐      互联网   20230620  4.27  4.65  4.23   4.53       4.28
# 14  300299.SZ  富春股份      互联网   20230620  9.31  9.91  9.22   9.60       9.40
# 16  002602.SZ  世纪华通      互联网   20230620  7.70  8.27  7.62   8.15       7.81
#
#     change  pct_chg  turnover_rate  turnover_rate_f  pe  pe_ttm  pb
# 1     0.30   3.1024            NaN              NaN NaN     NaN NaN
# 7     0.61   9.9673            NaN              NaN NaN     NaN NaN
# 9     0.39   4.2952            NaN              NaN NaN     NaN NaN
# 11    0.47   9.9366            NaN              NaN NaN     NaN NaN
# 12    0.25   5.8411            NaN              NaN NaN     NaN NaN
# 14    0.20   2.1277            NaN              NaN NaN     NaN NaN
# 16    0.34   4.3534            NaN              NaN NaN     NaN NaN

# %%
# df_index_daily.query("ts_code=='300315.SZ'")
df_index_daily
# Out:
#       ts_code trade_date      total_mv      float_mv   total_share
# 0   000001.SH   20230620  5.683810e+13  4.327845e+13  5.573962e+12  \
# 1   000005.SH   20230620  3.417394e+12  2.620724e+12  4.048807e+11
# 2   000006.SH   20230620  6.417915e+11  6.202727e+11  9.094996e+10
# 3   000016.SH   20230620  1.855167e+13  1.563546e+13  1.621899e+12
# 4   000300.SH   20230620  5.048196e+13  3.871230e+13  4.056791e+12
# 5   000905.SH   20230620  1.304180e+13  1.118485e+13  1.291725e+12
# 6   399001.SZ   20230620  2.272385e+13  1.887995e+13  1.278580e+12
# 7   399005.SZ   20230620  6.911817e+12  5.747422e+12  3.221771e+11
# 8   399006.SZ   20230620  5.814201e+12  4.431451e+12  1.385131e+11
# 9   399016.SZ   20230620  7.286415e+12  6.031366e+12  1.915599e+11
# 10  399300.SZ   20230620  5.048196e+13  3.871230e+13  4.056791e+12
#
#      float_share    free_share  turnover_rate  turnover_rate_f     pe  pe_ttm
# 0   4.306419e+12  1.774539e+12           0.66             1.60  13.18   13.05  \
# 1   3.136305e+11  1.580869e+11           0.74             1.47  11.38   10.83
# 2   8.805542e+10  4.171266e+10           0.63             1.32   7.94    7.85
# 3   1.277392e+12  3.568978e+11           0.22             0.80   9.88    9.82
# 4   3.013098e+12  1.106691e+12           0.41             1.11  12.07   11.86
# 5   1.136168e+12  6.017113e+11           0.94             1.77  22.25   23.48
# 6   1.090919e+12  6.349483e+11           1.13             1.94  24.04   23.90
# 7   2.789829e+11  1.508793e+11           1.12             2.07  22.08   21.63
# 8   1.086364e+11  7.792316e+10           1.46             2.03  35.15   33.41
# 9   1.716065e+11  1.173918e+11           1.81             2.64  32.87   31.18
# 10  3.013098e+12  1.106691e+12           0.41             1.11  12.07   11.86
#
#       pb
# 0   1.32
# 1   1.09
# 2   0.76
# 3   1.23
# 4   1.35
# 5   1.84
# 6   2.55
# 7   3.13
# 8   4.65
# 9   4.71
# 10  1.35

# %%
#查看某只股票的区间变动情况--单只股票

df_stock_detail=stock_daily('300043.SZ','20220101','20230620')
# 将日期转换为datetime格式  
# df_stock_detail['trade_date'] = df_stock_detail.to_datetime(df_stock_detail['trade_date'])  
df_stock_detail['trade_date']=pd.to_datetime(df_stock_detail['trade_date'])
# tweets_df['Time'] = pd.to_datetime(tweets_df['Time'])
# 按日期排序  
df_stock_detail = df_stock_detail.sort_values('trade_date')  

# 获取开盘价、最高价、最低价和收盘价，并创建一个新的DataFrame  
OHLC=pd.DataFrame({
    
 'Open': df_stock_detail['open'], 
 'High': df_stock_detail['high'],  
 'Low':df_stock_detail['low'],
 'Close': df_stock_detail['close']  
 })
# 创建K线图  
# OHLC.plot(kind='candle', figsize=(10, 5))  
# mpf.plot(OHLC,type='line')

# 添加图例和标签  
# plt.legend(loc='upper left') 

# 绘制收盘价图形  
fig, ax = plt.subplots()  
ax.plot(df_stock_detail['trade_date'], df_stock_detail['close'])  
ax.set_xlabel('trade_date')  
ax.set_ylabel('Close')  
plt.legend(loc='upper left') 
plt.show()
# df_stock_detail

# %%
#画K线图- 单只股票--mplfinance 画图
OHLC=pd.DataFrame({
 'tr_date':df_stock_detail['trade_date'], 
 'Open': df_stock_detail['open'], 
 'High': df_stock_detail['high'],  
 'Low':df_stock_detail['low'],
 'Close': df_stock_detail['close']  
 })

# 选取所需的列  
data = OHLC
# 创建K线图  
# fig, ax = plt.subplots()  
# data.plot(kind='line', ax=ax)  
data.tr_date = pd.to_datetime(data.tr_date)
data.index=data.tr_date
mpf.plot(data.tail(60), type='candle',mav=(3,6,9),show_nontrading=True)

# mpf.plot(df_new,type='candle',mav = (3),show_nontrading=True, volume=True)

  
# # 设置坐标轴标签和标题  
# ax.set_xlabel('trade_date')  
# ax.set_ylabel('close')  
# ax.set_title('K-Candle Chart')  
  
# # 显示图像  
# plt.show()

# %%
#画K线图- 单只股票--pyechart 画图
OHLC=pd.DataFrame({
 'tr_date':df_stock_detail['trade_date'], 
 'Open': df_stock_detail['open'], 
 'High': df_stock_detail['high'],  
 'Low':df_stock_detail['low'],
 'Close': df_stock_detail['close']  
 })

# 选取所需的列  
data = OHLC

# %%
df_stock_detail
# Out:
#      ts_code trade_date   open   high    low  close  pre_close  change
# 8  002197.SZ 2023-05-22  10.43  10.50  10.28  10.31      10.41   -0.10  \
# 7  002197.SZ 2023-05-23  10.28  10.32  10.06  10.06      10.31   -0.25
# 6  002197.SZ 2023-05-24  10.01  10.14   9.96  10.03      10.06   -0.03
# 5  002197.SZ 2023-05-25  10.08  10.22   9.83  10.07      10.03    0.04
# 4  002197.SZ 2023-05-26  10.09  10.26  10.01  10.26      10.07    0.19
# 3  002197.SZ 2023-05-29  10.40  10.46  10.27  10.32      10.26    0.06
# 2  002197.SZ 2023-05-30  10.30  10.48  10.14  10.48      10.32    0.16
# 1  002197.SZ 2023-05-31  10.45  10.68  10.39  10.64      10.48    0.16
# 0  002197.SZ 2023-06-01  10.56  11.05  10.53  10.95      10.64    0.31
#
#    pct_chg        vol      amount
# 8  -0.9606  125930.57  130357.516
# 7  -2.4248  117991.67  119717.794
# 6  -0.2982   99205.35   99746.608
# 5   0.3988  158723.77  158666.249
# 4   1.8868  146948.59  149319.411
# 3   0.5848  198603.80  206048.629
# 2   1.5504  195374.98  202706.496
# 1   1.5267  244974.04  259889.742
# 0   2.9135  397775.94  430706.723

# %%
df_selected['name']=df_selected.apply(lambda x:get_stock_name(x,df_stocks_age_gt3),axis=1)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9404\3604007438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['name']=df_selected.apply(lambda x:get_stock_name(x,df_stocks_age_gt3),axis=1)

# %%
df_selected[df_selected['name']=='诺思兰德']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File D:\python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_selected[df_selected['name']=='诺思兰德']
#
# File D:\python310\lib\site-packages\pandas\core\frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File D:\python310\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
df_stocks_age_gt3_base['turnover']=df_stocks_age_gt3_base.apply(lambda x:x['ts_code'],axis=1)

# %%
#成交额排名前100的股票代码
for ts_code in amount_n('20230421',10):
    print(ts_code)
# Out:
# 300750.SZ
# 002230.SZ
# 603019.SH
# 300418.SZ
# 000977.SZ
# 601360.SH
# 688981.SH
# 000988.SZ
# 000063.SZ
# 300059.SZ

# %%
#########以下为基本技术的验证############

# %%
df_selected['name']=df_selected.apply(lambda x:get_stock_name(x,df_stocks_age_gt3),axis=1)

# %%
# df_stocks.head(2)
#给行情信息名字
# def get_name(df):
#     df['name']=df[ts]
def get_stock_name(ts_code):
    name=df_stocks.query("ts_code=='{}'".format(ts_code))['name'][0]
    return name
# df_stocks.query("ts_code=='000001.SZ'")

# %%
# get_stock_name('000001.SZ')
#获取股票名称
def get_stock_name(df1,df2):
#     name=df.query("ts_code=='{}'".format(df['ts_code']))['name'][0]
    for ts_code in df1['ts_code']:
#         print(ts_code)
        for ts_code2 in df2['ts_code']:
            if  ts_code==ts_code2: 
#                  print(ts_code2,ts_code)   

                 print(df2[df2['ts_code']==ts_code2]['name'])

# %%
get_stock_name(df_selected,df_stocks_age_gt3)
# Out:
# 2773    诺思兰德
# Name: name, dtype: object
# 5070    三友科技
# Name: name, dtype: object
# 5027    安徽凤凰
# Name: name, dtype: object
# 5119    方大新材
# Name: name, dtype: object
# 5026    创远信科
# Name: name, dtype: object
# 5087    数字人
# Name: name, dtype: object
# 5035    鹿得医疗
# Name: name, dtype: object
# 5086    富士达
# Name: name, dtype: object
# 5147    常辅股份
# Name: name, dtype: object
# 4999    万通液压
# Name: name, dtype: object
# 5024    浩淼科技
# Name: name, dtype: object
# 4996    艾融软件
# Name: name, dtype: object
# 2778    苏轴股份
# Name: name, dtype: object
# 5069    恒拓开源
# Name: name, dtype: object
# 267    中交地产
# Name: name, dtype: object
# 288    甘咨询
# Name: name, dtype: object
# 942    杭氧股份
# Name: name, dtype: object
# 1604    易联众
# Name: name, dtype: object
# 1621    中航电测
# Name: name, dtype: object
# 1637    新国都
# Name: name, dtype: object
# 2268    值得买
# Name: name, dtype: object
# 2276    佳禾智能
# Name: name, dtype: object
# 2978    海南椰岛
# Name: name, dtype: object
# 2983    万通发展
# Name: name, dtype: object
# 2984    陕西建工
# Name: name, dtype: object
# 2995    北方股份
# Name: name, dtype: object
# 3635    杭齿前进
# Name: name, dtype: object
# 3660    青岛港
# Name: name, dtype: object
# 3667    广深铁路
# Name: name, dtype: object
# 4309    佳力图
# Name: name, dtype: object
# 4313    金桥信息
# Name: name, dtype: object
# 4318    中科软
# Name: name, dtype: object
# 301    中国武夷
# Name: name, dtype: object
# 315    美利云
# Name: name, dtype: object
# 332    财信发展
# Name: name, dtype: object
# 989    *ST广田
# Name: name, dtype: object
# 1647    中环装备
# Name: name, dtype: object
# 1671    天瑞仪器
# Name: name, dtype: object
# 1672    东方国信
# Name: name, dtype: object
# 1674    万达信息
# Name: name, dtype: object
# 2326    捷安高科
# Name: name, dtype: object
# 2338    协创数据
# Name: name, dtype: object
# 3670    三六零
# Name: name, dtype: object
# 3682    中新集团
# Name: name, dtype: object
# 3699    长城军工
# Name: name, dtype: object
# 4347    丸美股份
# Name: name, dtype: object
# 4360    读者传媒
# Name: name, dtype: object
# 4379    天正电气
# Name: name, dtype: object
# 1696    科德教育
# Name: name, dtype: object
# 1708    天喻信息
# Name: name, dtype: object
# 1715    易华录
# Name: name, dtype: object
# 2381    中胤时尚
# Name: name, dtype: object
# 3044    华发股份
# Name: name, dtype: object
# 3050    宏达股份
# Name: name, dtype: object
# 3053    国机汽车
# Name: name, dtype: object
# 3055    美克家居
# Name: name, dtype: object
# 3058    华夏幸福
# Name: name, dtype: object
# 3733    光大证券
# Name: name, dtype: object
# 388    福星股份
# Name: name, dtype: object
# 414    天保基建
# Name: name, dtype: object
# 1072    百润股份
# Name: name, dtype: object
# 1085    未名医药
# Name: name, dtype: object
# 1734    洲明科技
# Name: name, dtype: object
# 1737    方直科技
# Name: name, dtype: object
# 1752    初灵信息
# Name: name, dtype: object
# 2394    朗特智能
# Name: name, dtype: object
# 2395    特发服务
# Name: name, dtype: object
# 3087    宁沪高速
# Name: name, dtype: object
# 3093    金地集团
# Name: name, dtype: object
# 3098    五矿资本
# Name: name, dtype: object
# 3105    海澜之家
# Name: name, dtype: object
# 3114    小商品城
# Name: name, dtype: object
# 3758    中国银河
# Name: name, dtype: object
# 3765    南方传媒
# Name: name, dtype: object
# 3776    中国出版
# Name: name, dtype: object
# 3787    中国银行
# Name: name, dtype: object
# 439    新大陆
# Name: name, dtype: object
# 1110    中公教育
# Name: name, dtype: object
# 1122    美吉姆
# Name: name, dtype: object
# 1786    苏交科
# Name: name, dtype: object
# 1790    朗玛信息
# Name: name, dtype: object
# 1797    三六五网
# Name: name, dtype: object
# 1802    海峡创新
# Name: name, dtype: object
# 1805    聚飞光电
# Name: name, dtype: object
# 3812    中衡设计
# Name: name, dtype: object
# 3813    华设集团
# Name: name, dtype: object
# 4509    当虹科技
# Name: name, dtype: object
# 1158    中科金财
# Name: name, dtype: object
# 1160    凯文教育
# Name: name, dtype: object
# 1830    计通退
# Name: name, dtype: object
# 1838    ST开元
# Name: name, dtype: object
# 3874    新经典
# Name: name, dtype: object
# 4523    宝兰德
# Name: name, dtype: object
# 522    招商蛇口
# Name: name, dtype: object
# 541    *ST中捷
# Name: name, dtype: object
# 1181    奋达科技
# Name: name, dtype: object
# 1859    全通教育
# Name: name, dtype: object
# 1864    创意信息
# Name: name, dtype: object
# 1870    中铁装配
# Name: name, dtype: object
# 3239    八一钢铁
# Name: name, dtype: object
# 3891    红蜻蜓
# Name: name, dtype: object
# 3892    ST万林
# Name: name, dtype: object
# 3909    海量数据
# Name: name, dtype: object
# 4569    赛诺医疗
# Name: name, dtype: object
# 1227    燕塘乳业
# Name: name, dtype: object
# 1256    汇洁股份
# Name: name, dtype: object
# 1895    天利科技
# Name: name, dtype: object
# 3263    绿地控股
# Name: name, dtype: object
# 3270    丰华股份
# Name: name, dtype: object
# 3277    光大嘉宝
# Name: name, dtype: object
# 3282    华建集团
# Name: name, dtype: object
# 3286    国新文化
# Name: name, dtype: object
# 3289    浦东金桥
# Name: name, dtype: object
# 4613    步科股份
# Name: name, dtype: object
# 613    生意宝
# Name: name, dtype: object
# 1268    久远银海
# Name: name, dtype: object
# 1963    四方精创
# Name: name, dtype: object
# 3300    飞乐音响
# Name: name, dtype: object
# 3304    信达地产
# Name: name, dtype: object
# 3307    昂立教育
# Name: name, dtype: object
# 3327    金龙汽车
# Name: name, dtype: object
# 3973    雪峰科技
# Name: name, dtype: object
# 3977    格尔软件
# Name: name, dtype: object
# 3992    松发股份
# Name: name, dtype: object
# 4675    开普云
# Name: name, dtype: object
# 1995    启迪设计
# Name: name, dtype: object
# 2008    恒实科技
# Name: name, dtype: object
# 2011    久之洋
# Name: name, dtype: object
# 2015    科大国创
# Name: name, dtype: object
# 3345    光明地产
# Name: name, dtype: object
# 3356    祁连山
# Name: name, dtype: object
# 4698    卓易信息
# Name: name, dtype: object
# 1    万科A
# Name: name, dtype: object
# 11    沙河股份
# Name: name, dtype: object
# 24    大悦城
# Name: name, dtype: object
# 25    深桑达A
# Name: name, dtype: object
# 35    *ST泛海
# Name: name, dtype: object
# 675    三特索道
# Name: name, dtype: object
# 1366    中设股份
# Name: name, dtype: object
# 2030    农尚环境
# Name: name, dtype: object
# 2032    同益股份
# Name: name, dtype: object
# 2035    先进数通
# Name: name, dtype: object
# 2046    集智股份
# Name: name, dtype: object
# 2052    佳发教育
# Name: name, dtype: object
# 3382    上实发展
# Name: name, dtype: object
# 4049    设计总院
# Name: name, dtype: object
# 4063    顶点软件
# Name: name, dtype: object
# 4088    恒为科技
# Name: name, dtype: object
# 4724    鸿泉物联
# Name: name, dtype: object
# 4752    财富趋势
# Name: name, dtype: object
# 47    北方国际
# Name: name, dtype: object
# 716    ST交投
# Name: name, dtype: object
# 721    国统股份
# Name: name, dtype: object
# 744    鸿博股份
# Name: name, dtype: object
# 1389    德生科技
# Name: name, dtype: object
# 1393    中新赛克
# Name: name, dtype: object
# 1419    新疆交建
# Name: name, dtype: object
# 1426    华阳国际
# Name: name, dtype: object
# 2095    立昂技术
# Name: name, dtype: object
# 2098    金太阳
# Name: name, dtype: object
# 3419    轻纺城
# Name: name, dtype: object
# 3442    ST安信
# Name: name, dtype: object
# 3448    上海物贸
# Name: name, dtype: object
# 3451    新华传媒
# Name: name, dtype: object
# 3453    百联股份
# Name: name, dtype: object
# 4107    掌阅科技
# Name: name, dtype: object
# 4788    光云科技
# Name: name, dtype: object
# 106    渝开发
# Name: name, dtype: object
# 116    学大教育
# Name: name, dtype: object
# 759    滨江集团
# Name: name, dtype: object
# 788    桂林三金
# Name: name, dtype: object
# 1461    京北方
# Name: name, dtype: object
# 1466    宝明科技
# Name: name, dtype: object
# 2113    维业股份
# Name: name, dtype: object
# 2126    彩讯股份
# Name: name, dtype: object
# 2130    广和通
# Name: name, dtype: object
# 2137    正元智慧
# Name: name, dtype: object
# 2796    皖通高速
# Name: name, dtype: object
# 2820    保利发展
# Name: name, dtype: object
# 3462    海通证券
# Name: name, dtype: object
# 4135    引力传媒
# Name: name, dtype: object
# 131    中原环保
# Name: name, dtype: object
# 803    禾盛新材
# Name: name, dtype: object
# 805    奥飞娱乐
# Name: name, dtype: object
# 818    南国置业
# Name: name, dtype: object
# 820    北新路桥
# Name: name, dtype: object
# 826    *ST日海
# Name: name, dtype: object
# 828    焦点科技
# Name: name, dtype: object
# 1474    中岩大地
# Name: name, dtype: object
# 1478    竞业达
# Name: name, dtype: object
# 1486    地铁设计
# Name: name, dtype: object
# 1500    吉大正元
# Name: name, dtype: object
# 2145    世纪天鸿
# Name: name, dtype: object
# 2160    沪宁股份
# Name: name, dtype: object
# 2165    宇信科技
# Name: name, dtype: object
# 2166    建科院
# Name: name, dtype: object
# 2179    创业黑马
# Name: name, dtype: object
# 2184    盛弘股份
# Name: name, dtype: object
# 2840    中船科技
# Name: name, dtype: object
# 2861    同方股份
# Name: name, dtype: object
# 3539    江苏有线
# Name: name, dtype: object
# 4178    天马科技
# Name: name, dtype: object
# 4206    香飘飘
# Name: name, dtype: object
# 4213    中广天择
# Name: name, dtype: object
# 184    中油资本
# Name: name, dtype: object
# 864    漫步者
# Name: name, dtype: object
# 874    汉王科技
# Name: name, dtype: object
# 880    太极股份
# Name: name, dtype: object
# 1525    鼎汉技术
# Name: name, dtype: object
# 1534    银江技术
# Name: name, dtype: object
# 2220    设研院
# Name: name, dtype: object
# 4235    乾景园林
# Name: name, dtype: object
# 4905    山大地纬
# Name: name, dtype: object
# 4911    新致软件
# Name: name, dtype: object
# 225    视觉中国
# Name: name, dtype: object
# 245    贝瑞基因
# Name: name, dtype: object
# 885    千方科技
# Name: name, dtype: object
# 913    中远海科
# Name: name, dtype: object
# 921    雅克科技
# Name: name, dtype: object
# 1558    天源迪科
# Name: name, dtype: object
# 1569    蓝色光标
# Name: name, dtype: object
# 1584    数字政通
# Name: name, dtype: object
# 1587    思创医惠
# Name: name, dtype: object
# 1594    银之杰
# Name: name, dtype: object
# 2232    汉嘉设计
# Name: name, dtype: object
# 2252    迪普科技
# Name: name, dtype: object
# 2254    新媒股份
# Name: name, dtype: object
# 2262    新城市
# Name: name, dtype: object
# 2919    上海建工
# Name: name, dtype: object
# 2927    瑞茂通
# Name: name, dtype: object
# 2951    新湖中宝
# Name: name, dtype: object
# 3627    新城控股
# Name: name, dtype: object

# %%
df_tmp=stock_weekly('000001.SZ','20230421','20230516').head(100)

# %%
df_tmp
# Out:
#      ts_code trade_date  close   open   high    low  pre_close  change
# 0  000001.SZ   20230512  12.62  12.94  13.60  12.61      12.91   -0.29  \
# 1  000001.SZ   20230505  12.91  12.40  13.11  12.19      12.55    0.36
# 2  000001.SZ   20230428  12.55  12.48  12.78  11.99      12.50    0.05
# 3  000001.SZ   20230421  12.50  12.66  13.20  12.48      12.69   -0.19
#
#    pct_chg          vol        amount
# 0  -0.0225  807966857.0  1.060886e+10
# 1   0.0287  324045303.0  4.147127e+09
# 2   0.0040  621018085.0  7.630634e+09
# 3  -0.0150  558798369.0  7.182669e+09

# %%
# 沪深股通十大成交股
# df_tmp=get_source().hsgt_top10(trade_date='20230426', market_type='3')
# df_tmp

# %%
condition = (df_tmp['close']-df_tmp['open'])/df_tmp['open']>0.03
#获取满足条件的数据
df_tmp.loc[condition]
#获取满足条件的行索引
# df_tmp.loc[condition].index
# Out:
#       ts_code trade_date   open   high    low  close  pre_close  change
# 7   000009.SZ   20220902  14.60  15.33  14.40  15.09      14.43    0.66  \
# 15  000020.SZ   20220902   9.43   9.89   9.41   9.77       9.42    0.35
# 18  000025.SZ   20220902  18.55  19.95  18.55  19.15      18.40    0.75
# 26  000034.SZ   20220902  17.42  18.32  17.38  17.97      17.32    0.65
# 30  000038.SZ   20220902   4.63   4.85   4.63   4.83       4.66    0.17
# 34  000045.SZ   20220902   8.60   8.91   8.59   8.87       8.62    0.25
# 37  000049.SZ   20220902  51.01  53.99  50.48  52.72      50.21    2.51
# 41  000058.SZ   20220902   5.86   6.20   5.84   6.14       5.92    0.22
# 49  000068.SZ   20220902   3.89   4.13   3.70   4.13       3.75    0.38
# 51  000070.SZ   20220902   6.51   7.04   6.51   6.92       6.46    0.46
# 66  000159.SZ   20220902   8.80   9.11   8.62   9.07       8.75    0.32
# 78  000409.SZ   20220902   6.52   7.16   6.50   7.16       6.51    0.65
# 83  000416.SZ   20220902   4.30   4.71   4.30   4.48       4.28    0.20
#
#     pct_chg         vol       amount
# 7    4.5738   788862.84  1177303.263
# 15   3.7155    57574.01    55757.641
# 18   4.0761   150920.78   291811.604
# 26   3.7529   154548.58   276420.047
# 30   3.6481    53879.20    25797.709
# 34   2.9002   283834.34   249348.791
# 37   4.9990   135861.83   712678.653
# 41   3.7162   170761.20   103676.101
# 49  10.1333   561303.24   223888.053
# 51   7.1207   274781.13   187171.707
# 66   3.6571   165575.57   147525.102
# 78   9.9846   252993.08   178464.811
# 83   4.6729  1263264.76   580859.135

# %%
get_source().daily().query("ts_code=='002197.SZ'").head(10)
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change
# 3018  002197.SZ   20230420  11.42  11.61  11.34  11.58      11.41    0.17  \
#
#       pct_chg        vol      amount
# 3018   1.4899  317725.29  365419.187

# %%
#获取股票市场行业列表。
for industry in df_stocks['industry'].unique():
    if industry!=None:
        print(industry)
# Out:
# 银行
# 全国地产
# 软件服务
# 环境保护
# 区域地产
# 其他商业
# 运输设备
# 电气设备
# 建筑工程
# 玻璃
# 家用电器
# 服饰
# 农业综合
# 元器件
# 水泥
# 汽车服务
# 火力发电
# 医药商业
# 汽车配件
# 综合类
# 新型电力
# 多元金融
# 装修装饰
# 房产服务
# 商品城
# 石油加工
# 铅锌
# 通信设备
# IT设备
# 旅游景点
# 港口
# 机场
# 石油贸易
# 空运
# 生物制药
# 商贸代理
# 化学制药
# 影视音像
# 工程机械
# 证券
# 化纤
# 供气供热
# 农药化肥
# 机床制造
# 百货
# 中成药
# 酒店餐饮
# 路桥
# 造纸
# 医疗保健
# 食品
# 黄金
# 化工原料
# 专用机械
# 水运
# 日用化工
# 旅游服务
# 文教休闲
# 出版业
# 机械基件
# 汽车整车
# 煤炭开采
# 铁路
# 染料涂料
# 白酒
# 农用机械
# 林业
# 水务
# 水力发电
# 互联网
# 广告包装
# 铝
# 其他建材
# 批发业
# 保险
# 小金属
# 铜
# 普钢
# 航空
# 饲料
# 特种钢
# 种植业
# 仓储物流
# 焦炭加工
# 纺织
# 啤酒
# 超市连锁
# 钢加工
# 矿物制品
# 渔业
# 软饮料
# 化工机械
# 塑料
# 红黄酒
# 家居用品
# 摩托车
# 石油开采
# 轻工机械
# 电器仪表
# 半导体
# 乳制品
# 纺织机械
# 电器连锁
# 陶瓷
# 橡胶
# 公路
# 电信运营
# 公共交通
# 船舶
# 园区开发

# %%
# from datetime import datetime as dt
# from datetime import date,time
import time
from time import mktime
from datetime import datetime,timedelta
from dateutil.relativedelta import relativedelta

s='20210101'
e='20210102'
# 字符串转日期
s_date=datetime.strptime(s,'%Y%m%d')
e_date=datetime.strptime(e,'%Y%m%d')
#今天
today=datetime.today().date().strftime('%Y%m%d')
# 上一天
lastday=(datetime.today().date() - timedelta(days=1)).strftime('%Y%m%d')
#上一年
lastyear=(datetime.today().date() - relativedelta(months=12)).strftime('%Y%m%d')
print(s_date) ,print(e_date),print(today),print(lastday),print(lastyear)
# (e_date-s_date).month
# Out:
# 2021-01-01 00:00:00
# 2021-01-02 00:00:00
# 20230526
# 20230525
# 20220526
# (None, None, None, None, None)

# %%
import time
from time import mktime
from dateutil.relativedelta import relativedelta
from datetime import datetime,timedelta
  
# 获取当前日期  
s='20230526'
# e='20210102'
# today = datetime.date.today()  
# 字符串转日期
today=datetime.strptime(s)
  
# 获取周末日期  
weekend_date = today + datetime.timedelta(days=today.weekday())  
  
# 获取月末日期  
last_day_of_month = datetime.datetime(today.year, today.month, 1).strftime("%d")  
last_day_of_month = int(last_day_of_month)  
last_day_of_month += (30 - last_day_of_month) % 30  
  
print("Today is:", today)  
print("Weekend date:", weekend_date)  
print("Last day of month:", last_day_of_month)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       7 s='20230526'
#       8 # e='20210102'
#       9 # today = datetime.date.today()
#      10 # 字符串转日期
# ---> 11 today=datetime.strptime(s)
#      13 # 获取周末日期
#      14 weekend_date = today + datetime.timedelta(days=today.weekday())
#
# TypeError: strptime() takes exactly 2 arguments (1 given)

# %%
import time
from time import mktime
from datetime import datetime,timedelta
from dateutil.relativedelta import relativedelta

s='20210101'
e='20210102'
# 字符串转日期
s_date=datetime.strptime(s,'%Y%m%d')
e_date=datetime.strptime(e,'%Y%m%d')
lastday=(datetime.today().date() - timedelta(days=1)).strftime('%Y%m%d')

# %%
print(s_date,e_date,lastday)
# Out:
# 2021-01-01 00:00:00 2021-01-02 00:00:00 20230525
