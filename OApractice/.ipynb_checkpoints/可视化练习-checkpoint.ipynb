# %%
#超酷的可视化神器：cutecharts
#虚假数据入库，注意引用。https://www.cnblogs.com/hellangels333/p/9039784.html

# %%
#https://github.com/chenjiandongx/cutecharts

# %%
# from cutecharts.charts=import line

# %%
# !pip install lux-api
#https://lux-api.readthedocs.io/en/stable/source/getting_started/installation.html
# Out:
# Collecting lux-api
#   Downloading lux-api-0.5.1.tar.gz (127 kB)
#      ---------------------------------------- 0.0/127.0 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/127.0 kB 660.6 kB/s eta 0:00:01
#      ----------------- ------------------- 61.4/127.0 kB 825.8 kB/s eta 0:00:01
#      ------------------------------------ - 122.9/127.0 kB 1.2 MB/s eta 0:00:01
#      ------------------------------------ 127.0/127.0 kB 834.1 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scipy>=1.3.3 in d:\python310\lib\site-packages (from lux-api) (1.9.3)
# Collecting altair>=4.0.0 (from lux-api)
#   Downloading altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy>=1.16.5 in d:\python310\lib\site-packages (from lux-api) (1.23.5)
# Requirement already satisfied: pandas in d:\python310\lib\site-packages (from lux-api) (2.0.0)
# Requirement already satisfied: scikit-learn>=0.22 in d:\python310\lib\site-packages (from lux-api) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\python310\lib\site-packages (from lux-api) (3.6.3)
# Collecting lux-widget>=0.1.4 (from lux-api)
#   Downloading lux-widget-0.1.11.tar.gz (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      -- ------------------------------------- 0.2/2.5 MB 4.8 MB/s eta 0:00:01
#      ------ --------------------------------- 0.4/2.5 MB 5.1 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.7/2.5 MB 5.3 MB/s eta 0:00:01
#      -------------- ------------------------- 0.9/2.5 MB 5.0 MB/s eta 0:00:01
#      ------------------------- -------------- 1.6/2.5 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 4.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting autopep8>=1.5 (from lux-api)
#   Downloading autopep8-2.0.4-py2.py3-none-any.whl.metadata (17 kB)
# Collecting iso3166 (from lux-api)
#   Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: psutil>=5.9.0 in d:\python310\lib\site-packages (from lux-api) (5.9.5)
# Collecting sh (from lux-api)
#   Downloading sh-2.0.6-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jinja2 in d:\python310\lib\site-packages (from altair>=4.0.0->lux-api) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in d:\python310\lib\site-packages (from altair>=4.0.0->lux-api) (4.17.3)
# Requirement already satisfied: packaging in d:\python310\lib\site-packages (from altair>=4.0.0->lux-api) (23.1)
# Collecting toolz (from altair>=4.0.0->lux-api)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing-extensions>=4.0.1 in d:\python310\lib\site-packages (from altair>=4.0.0->lux-api) (4.6.3)
# Collecting pycodestyle>=2.10.0 (from autopep8>=1.5->lux-api)
#   Downloading pycodestyle-2.11.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting tomli (from autopep8>=1.5->lux-api)
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: notebook>=4.0.0 in d:\python310\lib\site-packages (from lux-widget>=0.1.4->lux-api) (6.5.4)
# Requirement already satisfied: ipywidgets>=7.5.0 in d:\python310\lib\site-packages (from lux-widget>=0.1.4->lux-api) (8.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python310\lib\site-packages (from matplotlib>=3.0.0->lux-api) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in d:\python310\lib\site-packages (from matplotlib>=3.0.0->lux-api) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python310\lib\site-packages (from matplotlib>=3.0.0->lux-api) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python310\lib\site-packages (from matplotlib>=3.0.0->lux-api) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in d:\python310\lib\site-packages (from matplotlib>=3.0.0->lux-api) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python310\lib\site-packages (from matplotlib>=3.0.0->lux-api) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python310\lib\site-packages (from matplotlib>=3.0.0->lux-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\python310\lib\site-packages (from pandas->lux-api) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\python310\lib\site-packages (from pandas->lux-api) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in d:\python310\lib\site-packages (from scikit-learn>=0.22->lux-api) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\python310\lib\site-packages (from scikit-learn>=0.22->lux-api) (3.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\python310\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.22.0)
# Requirement already satisfied: ipython>=6.1.0 in d:\python310\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\python310\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in d:\python310\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in d:\python310\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.7)
# Requirement already satisfied: attrs>=17.4.0 in d:\python310\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\python310\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.19.3)
# Requirement already satisfied: tornado>=6.1 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.3)
# Requirement already satisfied: pyzmq>=17 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (25.0.2)
# Requirement already satisfied: argon2-cffi in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (8.2.0)
# Requirement already satisfied: ipython-genutils in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: nbformat in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (5.8.0)
# Requirement already satisfied: nbconvert>=5 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (7.3.1)
# Requirement already satisfied: nest-asyncio>=1.5 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.17.1)
# Requirement already satisfied: prometheus-client in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in d:\python310\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.5)
# Requirement already satisfied: six>=1.5 in d:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->lux-api) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\python310\lib\site-packages (from jinja2->altair>=4.0.0->lux-api) (2.1.2)
# Requirement already satisfied: comm>=0.1.1 in d:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in d:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.6)
# Requirement already satisfied: backcall in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: decorator in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.18.2)
# Requirement already satisfied: pickleshare in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.15.1)
# Requirement already satisfied: stack-data in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.6.2)
# Requirement already satisfied: colorama in d:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in d:\python310\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.2.0)
# Requirement already satisfied: pywin32>=300 in d:\python310\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (306)
# Requirement already satisfied: jupyter-server>=1.8 in d:\python310\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in d:\python310\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.12.2)
# Requirement already satisfied: bleach in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.0.0)
# Requirement already satisfied: defusedxml in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.7.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.0)
# Requirement already satisfied: tinycss2 in d:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.2.1)
# Requirement already satisfied: fastjsonschema in d:\python310\lib\site-packages (from nbformat->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.16.3)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\python310\lib\site-packages (from terminado>=0.8.3->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in d:\python310\lib\site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\python310\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.8.3)
# Requirement already satisfied: anyio>=3.1.0 in d:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in d:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in d:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.4.4)
# Requirement already satisfied: websocket-client in d:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.57.0)
# Requirement already satisfied: wcwidth in d:\python310\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.6)
# Requirement already satisfied: cffi>=1.0.1 in d:\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\python310\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.4.1)
# Requirement already satisfied: webencodings in d:\python310\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.1)
# Requirement already satisfied: executing>=1.2.0 in d:\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.2.1)
# Requirement already satisfied: pure-eval in d:\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.2)
# Requirement already satisfied: idna>=2.8 in d:\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.4)
# Requirement already satisfied: sniffio>=1.1 in d:\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.3.0)
# Requirement already satisfied: pycparser in d:\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\python310\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in d:\python310\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.0)
# Requirement already satisfied: rfc3339-validator in d:\python310\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\python310\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.1)
# Requirement already satisfied: fqdn in d:\python310\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.1)
# Requirement already satisfied: isoduration in d:\python310\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\python310\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.3)
# Requirement already satisfied: uri-template in d:\python310\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in d:\python310\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in d:\python310\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.2.3)
# Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#    ---------------------------------------- 0.0/996.9 kB ? eta -:--:--
#    ---------------------------------------  993.3/996.9 kB ? eta -:--:--
#    ---------------------------------------  993.3/996.9 kB ? eta -:--:--
#    ---------------------------------------- 996.9/996.9 kB 7.9 MB/s eta 0:00:00
# Downloading autopep8-2.0.4-py2.py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.3 kB ? eta -:--:--
#    ------------------------------------ --- 41.0/45.3 kB ? eta -:--:--
#    ------------------------------------ --- 41.0/45.3 kB ? eta -:--:--
#    ---------------------------------------- 45.3/45.3 kB 322.0 kB/s eta 0:00:00
# Downloading sh-2.0.6-py3-none-any.whl (38 kB)
# Downloading pycodestyle-2.11.1-py2.py3-none-any.whl (31 kB)
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/56.1 kB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 51.2/56.1 kB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 51.2/56.1 kB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 51.2/56.1 kB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 51.2/56.1 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 56.1/56.1 kB 173.1 kB/s eta 0:00:00
# Building wheels for collected packages: lux-api, lux-widget
#   Building wheel for lux-api (pyproject.toml): started
#   Building wheel for lux-api (pyproject.toml): finished with status 'done'
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185638 sha256=b7de789e4c44fbb3c9b5fd6ef9a7c9cd11563acd49fa433ff17af7648011b5d9
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\29\2f\f5\d5fcd3111309d380314ce9ad7ed6eb2fe03b3315123bd0c2e9
#   Building wheel for lux-widget (pyproject.toml): started
#   Building wheel for lux-widget (pyproject.toml): finished with status 'done'
#   Created wheel for lux-widget: filename=lux_widget-0.1.11-py3-none-any.whl size=2540481 sha256=2b9025e6fcbbcc03eb7db7d340901e4e4755a4f24b5164b2e71e0eb17be91ce8
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\4d\f6\ce\bbd6194f5f69bc0b86bc7b278c766caf129cce86c016191905
# Successfully built lux-api lux-widget
# Installing collected packages: toolz, tomli, sh, pycodestyle, iso3166, autopep8, altair, lux-widget, lux-api
# Successfully installed altair-5.2.0 autopep8-2.0.4 iso3166-2.1.1 lux-api-0.5.1 lux-widget-0.1.11 pycodestyle-2.11.1 sh-2.0.6 tomli-2.0.1 toolz-0.12.1

# %%
# !jupyter nbextension install --py luxwidget
# Out:
# Installing D:\python310\lib\site-packages\luxwidget\nbextension/static -> luxwidget
# Making directory: C:\ProgramData\jupyter\nbextensions\luxwidget\
# Copying: D:\python310\lib\site-packages\luxwidget\nbextension\static\extension.js -> C:\ProgramData\jupyter\nbextensions\luxwidget\extension.js
# Copying: D:\python310\lib\site-packages\luxwidget\nbextension\static\index.js -> C:\ProgramData\jupyter\nbextensions\luxwidget\index.js
# Copying: D:\python310\lib\site-packages\luxwidget\nbextension\static\index.js.map -> C:\ProgramData\jupyter\nbextensions\luxwidget\index.js.map
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable luxwidget --py

# %%
# !jupyter nbextension enable --py luxwidget
# Out:
# Enabling notebook extension luxwidget/extension...
#       - Validating: ok

# %%
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager

# %%
import pandas as pd
import lux

# %%
data=pd.read_csv("./Data/Tatanic.csv")

# %%
data
# Out:
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\IPython\core\formatters.py:922: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# D:\python310\lib\site-packages\lux\core\frame.py:632: UserWarning:Traceback (most recent call last):
#   File "D:\python310\lib\site-packages\lux\core\frame.py", line 581, in _ipython_display_
#     self.maintain_metadata()
#   File "D:\python310\lib\site-packages\lux\core\frame.py", line 146, in maintain_metadata
#     self.compute_metadata()
#   File "D:\python310\lib\site-packages\lux\core\frame.py", line 126, in compute_metadata
#     lux.config.executor.compute_dataset_metadata(self)
#   File "D:\python310\lib\site-packages\lux\executor\PandasExecutor.py", line 448, in compute_dataset_metadata
#     self.compute_data_type(ldf)
#   File "D:\python310\lib\site-packages\lux\executor\PandasExecutor.py", line 506, in compute_data_type
#     elif check_if_id_like(ldf, attr):
#   File "D:\python310\lib\site-packages\lux\utils\utils.py", line 104, in check_if_id_like
#     diff = series.diff()
#   File "D:\python310\lib\site-packages\pandas\core\series.py", line 2871, in diff
#     result = algorithms.diff(self._values, periods)
#   File "D:\python310\lib\site-packages\pandas\core\algorithms.py", line 1453, in diff
#     out_arr[res_indexer] = op(arr[res_indexer], arr[lag_indexer])
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from google.colab import output
#       2 output.enable_custom_widget_manager()
#
# ModuleNotFoundError: No module named 'google'

# %%
lux.config.set_use_widget(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 lux.config.set_use_widget(True)
#
# AttributeError: 'Config' object has no attribute 'set_use_widget'

# %%
data
# Out:
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\IPython\core\formatters.py:922: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# D:\python310\lib\site-packages\lux\core\frame.py:632: UserWarning:Traceback (most recent call last):
#   File "D:\python310\lib\site-packages\lux\core\frame.py", line 581, in _ipython_display_
#     self.maintain_metadata()
#   File "D:\python310\lib\site-packages\lux\core\frame.py", line 146, in maintain_metadata
#     self.compute_metadata()
#   File "D:\python310\lib\site-packages\lux\core\frame.py", line 126, in compute_metadata
#     lux.config.executor.compute_dataset_metadata(self)
#   File "D:\python310\lib\site-packages\lux\executor\PandasExecutor.py", line 448, in compute_dataset_metadata
#     self.compute_data_type(ldf)
#   File "D:\python310\lib\site-packages\lux\executor\PandasExecutor.py", line 506, in compute_data_type
#     elif check_if_id_like(ldf, attr):
#   File "D:\python310\lib\site-packages\lux\utils\utils.py", line 104, in check_if_id_like
#     diff = series.diff()
#   File "D:\python310\lib\site-packages\pandas\core\series.py", line 2871, in diff
#     result = algorithms.diff(self._values, periods)
#   File "D:\python310\lib\site-packages\pandas\core\algorithms.py", line 1453, in diff
#     out_arr[res_indexer] = op(arr[res_indexer], arr[lag_indexer])
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
