# %%
# import tushare  as ts
import pandas as pd

# %%
print(ts.__version__)
# Out:
# 1.2.89

# %%
#设置token

# %%
# ts.set_token('03c7207214bc890b435abe6ec1d1a8a353dcdfbf7e323744968ffd73')

# %%
#初始化 pro

# %%
pro = ts.pro_api('8ceca20646e4fee899e039f75bfcafddee39fdc34b9ce073cdea7d0f')

# %%
#数据调取

# %%
df = pro.trade_cal(exchange='', start_date='20180901', end_date='20220531', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pro.trade_cal(exchange='', start_date='20180901', end_date='20220531', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/tushare/pro/client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您输入的TOKEN无效！

# %%
# df = pro.query('trade_cal', exchange='', start_date='20180901', end_date='20181001', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')

# %%
df.shape
# Out:
# (464, 4)

# %%
df_tr_periods=pro.trade_cal(exchange='SSE', is_open='1', 
                            start_date='20180901', 
                            end_date='20220531', 
                            fields='cal_date')

# %%
df_tr_periods.head(2)
# Out:
#    cal_date
# 0  20180903
# 1  20180904

# %%
#获取股票日报数据

# %%
def get_daily(self, ts_code='', trade_date='', start_date='', end_date=''):
    for _ in range(3):
        try:
            if trade_date:
                df = self.pro.daily(ts_code=ts_code, trade_date=trade_date)
            else:
                df = self.pro.daily(ts_code=ts_code, start_date=start_date, end_date=end_date)
        except:
                time.sleep(1)
        else:
                return df

# %%
class tushare_stock:
   #统一数据来源
    def get_source():
        pro = ts.pro_api('5fb9551d1e4c7339259b68703d554c50dd7cebc016fcfc8dd11fd438')
        return pro 
    #股票列表
    def get_data():
        df = get_source().stock_basic()
        return df

# %%
tushare_stock= tushare_stock()

# %%
tushare_stock.get_source()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tushare_stock.get_source()
#
# TypeError: tushare_stock.get_source() takes 0 positional arguments but 1 was given

# %%
#统一数据来源
def get_source():
    pro = ts.pro_api('5fb9551d1e4c7339259b68703d554c50dd7cebc016fcfc8dd11fd438')
    return pro
#股票列表
def get_data():
    df = get_source().stock_basic()
    return df
#交易日历
def get_cal():
        df_cal=get_source().trade_cal()
        return df_cal
#
#获取沪股通成分,hs_type:SH,SZ
def stock_kind(kind):
        df_type = get_source().hs_const(hs_type=kind) 
        return  df_type
#上市公司基本信息  交易所代码 ，exchange_name-SSE上交所 SZSE深交所
def company_info(exchange_name,ts_codes):
    df_company =get_source().stock_company(exchange=exchange_name,ts_code=ts_codes, fields='ts_code,chairman,manager,secretary,reg_capital,setup_date,province,city,introduction,website,employees,main_business,business_scope')
    return df_company
#上市公司管理层
def company_managers(ts_code,ann_date,start_date,end_date):
        df_managers= get_source().stk_managers(ts_code=ts_code,ann_date=ann_date,start_date=start_date,end_date=end_date)
        return  df_managers
#管理层持股数
def manager_stocks(ts_code,end_date):
        df_stocks= get_source().stk_rewards(ts_code=ts_code,end_date=end_date)
        return  df_stocks
#IPO新股
def new_stocks(start_date,end_date):
        df_news= get_source().new_share(start_date=start_date, end_date=end_date)
        return  df_news

# %%
#股票列表数据
#基本状况、财务指标状况、行业市场声誉和市场潜力、公司声誉和公司潜力，公司人员状况、领导能力。
df_stocks=get_data()
# 1、需求超过三年的上市公司股票列表
df_stocks_age_gt3=df_stocks.query('list_date <"20190101"')

# %%
from datetime import datetime,date,time

s='20210101'
e='20210102'
# 字符串转日期
s_date=datetime.strptime(s,'%Y%m%d')
e_date=datetime.strptime(e,'%Y%m%d')
# print(s_date) ,print(e_date),
(e_date-s_date).month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-f2c160fdfa74> in <module>
#       7 e_date=datetime.strptime(e,'%Y%m%d')
#       8 # print(s_date) ,print(e_date),
# ----> 9 (e_date-s_date).month
#
# AttributeError: 'datetime.timedelta' object has no attribute 'month'

# %%
# df_stocks_age_gt3.query('industry =="银行"')

# %%
print(type(df_stocks_age_gt3['list_date']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
for i in df_stocks_age_gt3['list_date']:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
# df_stocks_age_gt3.loc[df_stocks_age_gt3['industry'].str.contains('新型电力')]

# %%
# new_stocks('20220101','20220331').name.str.split(",")

# %%
# stock_kind("SZ").head(10)

# %%
get_cal().query('cal_date>="20220531"').shape
# Out:
# (215, 4)

# %%
df_stocks.shape
# Out:
# (4844, 7)

# %%
# df_stocks.query('ts_code=="000001.SZ" & market=="主板"')
# df_stocks.query('market=="主板"').head(5)
# df_stocks.query('industry=='None'').head(5)
# Out:
#   File "<ipython-input-38-39694752fdc1>", line 3
#     df_stocks.query('industry=='None'').head(5)
#                                    ^
# SyntaxError: invalid syntax

# %%
for industry in df_stocks['industry'].unique():
    if industry!=None:
        print(industry)
# Out:
# 银行
# 全国地产
# 软件服务
# 环境保护
# 区域地产
# 酒店餐饮
# 运输设备
# 电气设备
# 建筑工程
# 玻璃
# 家用电器
# 服饰
# 农业综合
# 元器件
# IT设备
# 水泥
# 汽车服务
# 其他商业
# 火力发电
# 医药商业
# 汽车配件
# 综合类
# 新型电力
# 多元金融
# 装修装饰
# 房产服务
# 商品城
# 石油加工
# 铅锌
# 批发业
# 通信设备
# 旅游景点
# 港口
# 机场
# 石油贸易
# 空运
# 生物制药
# 商贸代理
# 化学制药
# 影视音像
# 工程机械
# 证券
# 化纤
# 供气供热
# 农药化肥
# 机床制造
# 百货
# 中成药
# 路桥
# 造纸
# 食品
# 黄金
# 化工原料
# 医疗保健
# 专用机械
# 水运
# 日用化工
# 旅游服务
# 文教休闲
# 出版业
# 机械基件
# 汽车整车
# 煤炭开采
# 铁路
# 染料涂料
# 白酒
# 林业
# 水务
# 水力发电
# 互联网
# 广告包装
# 铝
# 其他建材
# 保险
# 园区开发
# 小金属
# 铜
# 普钢
# 航空
# 饲料
# 特种钢
# 种植业
# 仓储物流
# 焦炭加工
# 纺织
# 啤酒
# 超市连锁
# 钢加工
# 矿物制品
# 渔业
# 农用机械
# 软饮料
# 化工机械
# 塑料
# 红黄酒
# 家居用品
# 摩托车
# 石油开采
# 电器仪表
# 半导体
# 乳制品
# 纺织机械
# 电器连锁
# 陶瓷
# 轻工机械
# 橡胶
# 公路
# 电信运营
# 公共交通
# 船舶

# %%
df_stocks[df_stocks['industry'].str.contains('汽车服务')==True]
# Out:
#         ts_code  symbol  name area industry market list_date
# 18    000025.SZ  000025   特力A   深圳     汽车服务     主板  19930621
# 274   000753.SZ  000753  漳州发展   福建     汽车服务     主板  19970626
# 438   000996.SZ  000996  中国中期   北京     汽车服务     主板  20000718
# 1217  002758.SZ  002758  浙农股份   浙江     汽车服务    中小板  20150527
# 1574  300100.SZ  300100  双林股份   浙江     汽车服务    创业板  20100806
# 2272  300825.SZ  300825   阿尔特   北京     汽车服务    创业板  20200327
# 2606  301215.SZ  301215  中汽股份   江苏     汽车服务    创业板  20220308
# 2883  600297.SH  600297  广汇汽车   辽宁     汽车服务     主板  20001116
# 2957  600386.SH  600386  北巴传媒   北京     汽车服务     主板  20010216
# 3164  600653.SH  600653  申华控股   辽宁     汽车服务     主板  19901219
# 3512  601258.SH  601258  庞大集团   河北     汽车服务     主板  20110428
# 3636  601965.SH  601965  中国汽研   重庆     汽车服务     主板  20120611
# 3890  603377.SH  603377  东方时尚   北京     汽车服务     主板  20160205

# %%
df_stocks[(df_stocks['list_date'].values=='19910114')==True]
# Out:
#      ts_code  symbol  name area industry market list_date
# 2  000004.SZ  000004  ST国华   深圳     软件服务     主板  19910114

# %%
df_stocks[(df_stocks['name'].str.contains('长安汽车'))==True]
# Out:
#        ts_code  symbol  name area industry market list_date
# 191  000625.SZ  000625  长安汽车   重庆     汽车整车     主板  19970610

# %%
for date in df_tr_periods['cal_date'].values:
#     print(date)
      df_exchange = get_daily( , '',date,''  ,'')
# Out:
#   File "<ipython-input-38-09aa207993ff>", line 3
#     df_exchange = get_daily( , '',date,''  ,'')
#                              ^
# SyntaxError: invalid syntax

# %%
#存入数据库

# %%
import sqlalchemy
from sqlalchemy import create_engine
connect_info='mysql+pymysql://root:w@localhost:3306/whgtest'
engine=sqlalchemy.create_engine(connect_info)

# %%
df.to_sql('stock_basic', engine, index=False, if_exists='append', chunksize=5000)

# %% [markdown]
# # 3系统层面的操作，比如文件操作

# %%
# !pwd
# Out:
# /home/jovyan/OApractice

# %%
# !cd ../  ;pwd;ls
# Out:
# /home/jovyan
# Data			scikit-learn.ipynb		  技术路线.xmind
# environment.yml		Sklearn2.ipynb			  机器学习练习册.ipynb
# home_test.txt		StudyPlace.ipynb		  案例学习
# OApractice		test_client.ui			  深度学习.ipynb
# postBuild		test_whg.txt			  爬虫学习.ipynb
# pushtogithub_home.sh	XGBoost.ipynb			  线性回归练习.ipynb
# pushtogithub_office.sh	函数图像.ipynb
# readme2.txt		客户精精准画像实施放案提纲.xmind

# %%
# !cd ../ ;cat pushtogithub_office.sh
# Out:
# #！/bin/sh
# read -p "输入要上传的文件,如果是全部请直接回车:" file_name
# read -p "更新描述:" description
# #echo "welcome $file_name"
# if [ ${file_name} =='' ] ; then
#    file_name="*"
# fi
# echo "welcome $file_name"
# echo "第一步：查看当前的git仓库状态，可以使用git status"
# git status
# echo "第二步：更新全部"
# git add ${file_name}
# echo "第三步：接着输入git commit -m "$description""
# git commit -m "${description}"
# echo "第四步：先git pull,拉取当前分支最新代码"
# git config --global pull.rebase true
# git pull
# echo "第五步：push到远程master分支上"
# git push -u  origin_new master
# echo "如有问题，请查看.git 目录下的config文件"

# %%
# !cd /home/jovyan/.git;ls
# Out:
# branches  description  hooks  info  objects    packed-refs
# config	  HEAD	       index  logs  ORIG_HEAD  refs

# %%
# !cd ../;ssh-keygen -t rsa -C “whgloveu@hotmail.com”
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/home/jovyan/.ssh/id_rsa): ^C

# %%
# !cd ../ssh/id_rsa;pwd
# Out:
# /bin/bash: line 0: cd: ../ssh/id_rsa: No such file or directory
# /home/jovyan/OApractice

# %%
# !git --version
# Out:
# git version 2.17.1
