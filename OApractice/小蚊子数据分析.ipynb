# %% [markdown]
# # 数据分析概况

# %%
# !pip install pyecharts

# %%
# ! python.exe -m pip install --upgrade pip

# %%
from pyecharts import options as opts
from pyecharts.charts import Tree
data = [
    {
        "name": "数据分析",
        "children": [
            {"name": "数据分析定义",
            "children": [{"name": "     数据分析是指根据分析目的，\n用适当的分析方法\n及工具，对数据进行处理与分析，\n提取有价值的信息，形成有效结论的过程"}]},
            {"name": "数据分析作用",
            "children": [{"name": "现状分析：发生了什么"}, {"name":"原因分析: 为什么发生"},{"name": "预测分析：将发生什么"}]},
            {"name": "数据分析步骤",
            "children": [{"name": "明确分析目的和思路"}, {"name": "数据收集","children":[{"name":"数据库"},{"name":"出版物"},{"name":"互联网"},{"name":"市场调查"}]},{"name":"数据处理","children":[{"name":"数据导入\导出"},{"name":"数据清洗"},{"name":"数据转换"},{"name":"数据抽取"},{"name":"数据合并"},{"name":"数据计算等"}]},{"name":"分析数据"},{"name":"数据展现"},{"name":"报告撰写"},]},
            {"name": "元组",
             "children": [{"name": "实例1：(1,2,3)}"}, {"name": "实例2：(a,b,c)"}]}
]}
]
c = (
    Tree()
    .add("", data)
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c5ed28c17da4207b883bd76f78880bd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c5ed28c17da4207b883bd76f78880bd = echarts.init(
#                     document.getElementById('4c5ed28c17da4207b883bd76f78880bd'), 'white', {renderer: 'canvas'});
#                 var option_4c5ed28c17da4207b883bd76f78880bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...
