# %%
#超酷的可视化神器：cutecharts
#虚假数据入库，注意引用。https://www.cnblogs.com/hellangels333/p/9039784.html

# %%
#https://github.com/chenjiandongx/cutecharts

# %%
# from cutecharts.charts=import line

# %%
# !pip install lux-api
#https://lux-api.readthedocs.io/en/stable/source/getting_started/installation.html

# %%
# !jupyter nbextension install --py luxwidget
# Out:
# Installing D:\python310\lib\site-packages\luxwidget\nbextension/static -> luxwidget
# Making directory: C:\ProgramData\jupyter\nbextensions\luxwidget\
# Copying: D:\python310\lib\site-packages\luxwidget\nbextension\static\extension.js -> C:\ProgramData\jupyter\nbextensions\luxwidget\extension.js
# Copying: D:\python310\lib\site-packages\luxwidget\nbextension\static\index.js -> C:\ProgramData\jupyter\nbextensions\luxwidget\index.js
# Copying: D:\python310\lib\site-packages\luxwidget\nbextension\static\index.js.map -> C:\ProgramData\jupyter\nbextensions\luxwidget\index.js.map
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable luxwidget --py

# %%
# !jupyter nbextension enable --py luxwidget
# Out:
# Enabling notebook extension luxwidget/extension...
#       - Validating: ok

# %%
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
# An error occurred.
# PermissionError: [WinError 5] 拒绝访问。: 'D:\\ProgramData\\anaconda3\\share\\jupyter\\lab\\extensions'
# See the log file for details:  C:\Users\admin\AppData\Local\Temp\jupyterlab-debug-k15_kuf5.log

# %%
# !jupyter labextension install luxwidget
# Out:
# An error occurred.
# PermissionError: [WinError 5] 拒绝访问。: 'D:\\ProgramData\\anaconda3\\share\\jupyter\\lab\\extensions'
# See the log file for details:  C:\Users\admin\AppData\Local\Temp\jupyterlab-debug-f0kau_l1.log

# %%
import pandas as pd
import lux

# %%
data=pd.read_csv("./Data/Tatanic.csv")

# %%
data
# Out:
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from google.colab import output
#       2 output.enable_custom_widget_manager()
#
# ModuleNotFoundError: No module named 'google'

# %%
lux.config.set_use_widget(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 lux.config.set_use_widget(True)
#
# AttributeError: 'Config' object has no attribute 'set_use_widget'

# %%
data
# Out:
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# D:\python310\lib\site-packages\lux\executor\PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %% [markdown]
# # 二、词云图

# %% [markdown]
# ## （一）英文词云

# %%
#词云图
# 摘要： 当我们手中有一篇文档，比如书籍、小说、电影剧本，若想快速了解其主要内容是什么，则可以采用绘制 WordCloud 词云图，显示主要的关键词（高频词）这种方式，非常方便。
# 本文将介绍常见的英文和中文文本的词云图绘制，以及 Frequency 频词频词云图。

# %%
# !pip install wordcloud
# https://zhuanlan.zhihu.com/p/58855751

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud ,STOPWORDS
import numpy as np
from PIL import Image
import os
from os import path

# %%
#获取当前文件路径
d=(path.dir_name(_file_) if "_file_" in locals() else os.getcwd())+"\Data"
#获取文本
text=open(path.join(d,'wordcloud.txt')).read()
#生成词云
wc=WordCloud(scale=2,
             background_color='black',
             max_font_size = 100,
             colormap = 'Blues')
wc.generate_from_text(text)
#显示图像
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.tight_layout()
#存储图像
wc.to_file('./Data/1900_basic.png')
plt.savefig('./Data/1900_basic.png',dpi=200)
plt.show()

# %%
 #   wordcloud.WordCloud(
 #   font_path=None,  # 字体路径，英文不用设置路径，中文需要，否则无法正确显示图形
 #   width=400, # 默认宽度
 #   height=200, # 默认高度
 #   margin=2, # 边缘
 #   ranks_only=None, 
 #   prefer_horizontal=0.9, 
 #   mask=None, # 背景图形，如果想根据图片绘制，则需要设置
 #   scale=1, 
 #   color_func=None, 
 #   max_words=200, # 最多显示的词汇量
 #   min_font_size=4, # 最小字号
 #   stopwords=None, # 停止词设置，修正词云图时需要设置
 #   random_state=None, 
 #   background_color='black', # 背景颜色设置，可以为具体颜色,比如white或者16进制数值
 #   max_font_size=None, # 最大字号
 #   font_step=1, 
 #   mode='RGB', 
 #   relative_scaling='auto', 
 #   regexp=None, 
 #   collocations=True, 
 #   colormap='viridis', # matplotlib 色图，可更改名称进而更改整体风格
 #   normalize_plurals=True, 
 #   contour_width=0, 
 #   contour_color='black', 
 #   repeat=False)

# %%
# !pip install imread
# Out:
# ...
#      ---------------------------------------- 0.0/130.0 kB ? eta -:--:--
#      ----------- ------------------------- 41.0/130.0 kB 487.6 kB/s eta 0:00:01
#      -------------------------------- ----- 112.6/130.0 kB 1.1 MB/s eta 0:00:01
#      ----------------------------------- -- 122.9/130.0 kB 1.0 MB/s eta 0:00:01
#      ------------------------------------ 130.0/130.0 kB 696.4 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build imread
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [83 lines of output]
# ...

# %%
# !pip install imageio

# %%
import os
from os import path
import numpy as np
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
from PIL import Image
from matplotlib import pyplot as plt
# from scipy.misc import imread
import imageio
import random

# %%
import os
from os import path
import numpy as np
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
from PIL import Image
from matplotlib import pyplot as plt
# from scipy.misc import imread
import imageio
import random

def wc_english():
    # 获取当前文件路径
    d=(path.dir_name(_file_) if "_file_" in locals() else os.getcwd())+"\Data"
    print(d)
    # 获取文本text
    text=open(path.join(d,'wordcloud.txt')).read()
    # 读取背景图片
#     background_Image = np.array(imageio.imread(path.join(d, "\image\mask1900.jpg")))
    background_Image = imageio.imread(path.join(d, "..\image\mask1900.jpg"))
    # or
    # background_Image = imread(path.join(d, "mask1900.jpg"))
    # 提取背景图片颜色
    img_colors = ImageColorGenerator(background_Image)
    # 设置英文停止词
    stopwords = set(STOPWORDS)
    wc = WordCloud(
        margin = 2, # 设置页面边缘
        mask = background_Image,
        scale = 2,
        max_words = 300, # 最多词个数
        min_font_size = 4, # 最小字体大小
        stopwords = stopwords,
        random_state = 42,
        background_color = 'white', # 背景颜色
        max_font_size = 150, # 最大字体大小
        )
    # 生成词云
    wc.generate_from_text(text)
    # 等价于
    # wc.generate(text)
    # 根据图片色设置背景色
    wc.recolor(color_func=img_colors)
    #存储图像
    wc.to_file('./image/1900pro1.png')
    # 显示图像
    plt.imshow(wc,interpolation='bilinear')
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
wc_english()
# Out:
# F:\jupyterfiles\OApractice\Data
# C:\Users\admin\AppData\Local\Temp\ipykernel_8720\3856318472.py:19: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   background_Image = imageio.imread(path.join(d, "..\image\mask1900.jpg"))

# %%
import os
from os import path
import numpy as np
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
from PIL import Image
from matplotlib import pyplot as plt
# from scipy.misc import imread
import imageio
import random
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
        return "hsl(0, 0%%, %d%%)" % random.randint(50, 100)

def wc_english():
    # 获取当前文件路径
    d=(path.dir_name(_file_) if "_file_" in locals() else os.getcwd())+"\Data"
    print(d)
    # 获取文本text
    text=open(path.join(d,'wordcloud.txt')).read()

    # 读取背景图片
#     background_Image = np.array(imageio.imread(path.join(d, "\image\mask1900.jpg")))
    background_Image = imageio.imread(path.join(d, "..\image\mask1900.jpg"))
    # or
    # background_Image = imread(path.join(d, "mask1900.jpg"))
    # 提取背景图片颜色
    img_colors = ImageColorGenerator(background_Image)
    # 设置英文停止词
    stopwords = set(STOPWORDS)
    stopwords.add('country')
    wc = WordCloud(
        margin = 2, # 设置页面边缘
        mask = background_Image,
        scale = 2,
        max_words = 200, # 最多词个数
        min_font_size = 4, # 最小字体大小
        stopwords = stopwords,
        random_state = 42,
        background_color = 'white', # 背景颜色
        max_font_size = 150, # 最大字体大小
        )
   

    # 生成词云
    wc.generate_from_text(text)
    # 等价于
    # wc.generate(text)
    # 根据图片色设置背景色
    wc.recolor(color_func=img_colors)
    # 随机设置hsl色值
#     wc.recolor(color_func=grey_color_func)
    #存储图像
    wc.to_file('./image/1900pro1.png')
    # 显示图像
    plt.imshow(wc,interpolation='bilinear')
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
wc_english()
 # 获取文本词排序，可调整 stopwords
process_word = WordCloud.process_text(wc,text)
sort = sorted(process_word.items(),key=lambda e:e[1],reverse=True)
print(sort[:50])
# Out:
# F:\jupyterfiles\OApractice\Data
# C:\Users\admin\AppData\Local\Temp\ipykernel_8720\3550440035.py:23: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   background_Image = imageio.imread(path.join(d, "..\image\mask1900.jpg"))
# ...

# %% [markdown]
# ## （二）中文词云

# %%
# 相比于英文词云，中文在绘制词云图前，需要先切割词汇，这里推荐使用 jieba 包来切割分词。因为它可以说是最好的中文分词包了，
# GitHub 上拥有 160 K 的 Star 数。安装好 jieba 包后，我们就可以对文本进行分词然后生成词云。

# %%
# jieba 分词有 3 种方式：精确模式、全模式和搜索引擎模式

# %%
# !pip install jieba
# !pip install chardet
# !python -m pip install --upgrade pip

# %%
import chardet
import os
d=(path.dir_name(_file_) if "_file_" in locals() else os.getcwd())+"\Data"
text = open(path.join(d + "\\benshu",'gaicibi.txt'),'rb').read()
text_charInfo = chardet.detect(text)
print(text_charInfo)
# Out:
# {'encoding': 'GB2312', 'confidence': 0.99, 'language': 'Chinese'}

# %%
# 获取文本词排序，可调整 stopwords
process_word = WordCloud.process_text(wc,text)
sort = sorted(process_word.items(),key=lambda e:e[1],reverse=True)
print(sort[:50]) # # 获取文本词频最高的前50个词
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # 获取文本词排序，可调整 stopwords
# ----> 2 process_word = WordCloud.process_text(wc,text)
#       3 sort = sorted(process_word.items(),key=lambda e:e[1],reverse=True)
#       4 print(sort[:50]) # # 获取文本词频最高的前50个词
#
# File D:\python310\lib\site-packages\wordcloud\wordcloud.py:582, in WordCloud.process_text(self, text)
#     579 pattern = r"\w[\w']*" if self.min_word_length <= 1 else r"\w[\w']+"
#     580 regexp = self.regexp if self.regexp is not None else pattern
# --> 582 words = re.findall(regexp, text, flags)
#     583 # remove 's
#     584 words = [word[:-2] if word.lower().endswith("'s") else word
#     585          for word in words]
#
# File D:\python310\lib\re.py:240, in findall(pattern, string, flags)
#     232 def findall(pattern, string, flags=0):
# ...

# %%
import os
from os import path
import numpy as np
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
from PIL import Image
from matplotlib import pyplot as plt
# from scipy.misc import imread
import imageio
import random
import chardet
import jieba
# 设置中文字体
font_path = r"C:\Users\admin\AppData\Local\Microsoft\Windows\Fonts\DroidSansMono.ttf" # 思源黑体
print(font_path)
# 读取背景图片
# background_Image = np.array(Image.open(path.join(d, "wave.png")))
d=(path.dir_name(_file_) if "_file_" in locals() else os.getcwd())+"\Data"
print(d)
text = open(path.join(d + "\\benshu",'gaicibi.txt')).read()
text += ' '.join(jieba.cut(text,cut_all=False)) # cut_all=False 表示采用精确模式
background_Image = imageio.imread(path.join(d, "..\image\mask1900.jpg"))
# 提取背景图片颜色
img_colors = ImageColorGenerator(background_Image)
# 设置中文停止词
stopwords = set('')
stopwords.update(['但是','的','我','一个','自己','因此','没有','很多','可以','这个','虽然','因为','这样','已经','现在','一些','比如','不是','当然','可能','如果','就是','同时','比如','这些','必须','由于','而且','并且','他们'])

wc = WordCloud(
        font_path = font_path, # 中文需设置路径
        margin = 2, # 页面边缘
        mask = background_Image,
        scale = 2,
        max_words = 200, # 最多词个数
        min_font_size = 4, #
        stopwords = stopwords,
        random_state = 42,
        background_color = 'white', # 背景颜色
        # background_color = '#C3481A', # 背景颜色
        max_font_size = 100,
        )
wc.generate(text)
# wc.generate_from_text(text)
# 获取文本词排序，可调整 stopwords
process_word = WordCloud.process_text(wc,text)
sort = sorted(process_word.items(),key=lambda e:e[1],reverse=True)
print(sort[:50]) # 获取文本词频最高的前50个词
# 设置为背景色，若不想要背景图片颜色，就注释掉
wc.recolor(color_func=img_colors)
# 存储图像
wc.to_file('./image/gaicibi.png')
# 显示图像

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Microsoft\Windows\Fonts\DroidSansMono.ttf
# F:\jupyterfiles\OApractice\Data
# C:\Users\admin\AppData\Local\Temp\ipykernel_8720\2937666802.py:21: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   background_Image = imageio.imread(path.join(d, "..\image\mask1900.jpg"))
# ...

# %% [markdown]
# # 五、 python和AUTOCAD

# %%
# 研究下python和CAD的关系，设计房屋和家具时可用。
# https://zhuanlan.zhihu.com/p/149792281

# %% [markdown]
# # 六、

# %%
# !python -V
# Out:
# Python 3.10.10
