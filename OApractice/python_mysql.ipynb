# %%
#python 操作mysql
#增删改查。

# %%
import pymysql

# %%
mysql_conn = pymysql.connect(host= '127.0.0.1', port= 3317, user= 'root', password= '', db= 'whgtest')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 mysql_conn = pymysql.connect(host= '127.0.0.1', port= 3317, user= 'root', password= '', db= 'whgtest')
#
# File D:\python310\lib\site-packages\pymysql\connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351     self._sock = None
#     352 else:
# --> 353     self.connect()
#
# ...

# %%
mysql_conn

# %%
text = "let's go"
text = mysql_conn.escape(text)
sql = "INSERT INTO test_mysql (name, num, text) VALUES ('{0}','{1}', {2})".format('Zarten_1', 1, text)
try:
    with mysql_conn.cursor() as cursor:
        cursor.execute(sql)
    mysql_conn.commit()
except Exception as e:
    mysql_conn.rollback()
mysql_conn.close()

# %%
#批量执行sql文件，非查询语句。
# %%time
mysql_conn = pymysql.connect(host= '127.0.0.1', port= 3306, user= 'root', password= '  ', db= 'whgtest')
with open("./sql/test.sql",encoding="utf-8") as f:
    full_sql=f.read();
    sql_commands=full_sql.split(';')[:-1]
#     print(full_sql)
for sql_command in sql_commands:
    try:
        mysql_conn.cursor().execute(sql_command)
        mysql_conn.commit()
    except Exception as e:
        mysql_conn.rollback()
        print(e)
mysql_conn.cursor().close()
mysql_conn.close()

# %%
#批量执行sql文件，查询语句

# %%
#excel表导入数据库（每10000条写入到数据库一次）

# %%
import pymysql
import xlrd
import sysimport pymysql
import xlrd
import sys
'''
    连接数据库
    args：db_name（数据库名称）
    returns:db
'''
 
 
def mysql_link(db_name):
    try:
        db = pymysql.connect(host="127.0.0.1", user="root",
                             passwd="",
                             db=db_name,
                             charset='utf8')
        return db
    except:
        print("could not connect to mysql server")
        
'''
    读取excel函数
    args：excel_file（excel文件，目录在py文件同目录）
    returns：book
'''
 
 
def open_excel(excel_file):
    try:
        book = xlrd.open_workbook(excel_file)  # 文件名，把文件与py文件放在同一目录下
        print(sys.getsizeof(book))
        return book
    except:
        print("open excel file failed!")
 
 
'''
    执行插入操作
    args:db_name（数据库名称）
         table_name(表名称）
         excel_file（excel文件名，把文件与py文件放在同一目录下）
 
'''
 
 
def store_to(db_name, table_name, excel_file):
    db = mysql_link(db_name)  # 打开数据库连接
    cursor = db.cursor()  # 使用 cursor() 方法创建一个游标对象 cursor
 
    book = open_excel(excel_file)  # 打开excel文件
    sheets = book.sheet_names()  # 获取所有sheet表名
    for sheet in sheets:
        sh = book.sheet_by_name(sheet)  # 打开每一张表
        row_num = sh.nrows
        print(row_num)
        list = []  # 定义列表用来存放数据
        num = 0  # 用来控制每次插入的数量
        for i in range(1, row_num):  # 第一行是标题名，对应表中的字段名所以应该从第二行开始，计算机以0开始计数，所以值是1
            row_data = sh.row_values(i)  # 按行获取excel的值
            value = (row_data[0], row_data[1], row_data[2])
            list.append(value)  # 将数据暂存在列表
            print(list)
            num += 1
            if( num>= 10000 ):  # 每一万条数据执行一次插入
                print(sys.getsizeof(list))
                sql = "INSERT INTO " + table_name + " (name, num, text)\
                VALUES(%s,%s,%s)"
#                 print(sql)
                cursor.executemany(sql, list)  # 执行sql语句
 
                num = 0  # 计数归零
                list.clear()  # 清空list
                print("worksheets: " + sheet + " has been inserted 10000 datas!")
            else:
                print(sys.getsizeof(list))
                sql = "INSERT INTO " + table_name + " (name, num, text)\
                VALUES(%s,%s,%s)"
#                 print(sql)
                cursor.executemany(sql, list)  # 执行sql语句
#                 print("worksheets: " + sheet + " has been inserted"+ str(num) +"datas!")
                num = 0  # 计数归零
                list.clear()  # 清空list
                
    print("worksheets: " + sheet + " has been inserted " + str(row_num) + " datas!")
    db.commit()  # 提交
    cursor.close()  # 关闭连接
    db.close()
 
if __name__ == '__main__':
    store_to('whgtest', 'test_mysql2', 'test.xlsx')
'''
    连接数据库
    args：db_name（数据库名称）
    returns:db
'''
 
 
def mysql_link(db_name):
    try:
        db = pymysql.connect(host="127.0.0.1", user="root",
                             passwd="",
                             db=db_name,
                             charset='utf8')
        return db
    except:
        print("could not connect to mysql server")
        
'''
    读取excel函数
    args：excel_file（excel文件，目录在py文件同目录）
    returns：book
'''
 
 
def open_excel(excel_file):
    try:
        book = xlrd.open_workbook(excel_file)  # 文件名，把文件与py文件放在同一目录下
        print(sys.getsizeof(book))
        return book
    except:
        print("open excel file failed!")
 
 
'''
    执行插入操作
    args:db_name（数据库名称）
         table_name(表名称）
         excel_file（excel文件名，把文件与py文件放在同一目录下）
 
'''
 
 
def store_to(db_name, table_name, excel_file):
    db = mysql_link(db_name)  # 打开数据库连接
    cursor = db.cursor()  # 使用 cursor() 方法创建一个游标对象 cursor
 
    book = open_excel(excel_file)  # 打开excel文件
    sheets = book.sheet_names()  # 获取所有sheet表名
    for sheet in sheets:
        sh = book.sheet_by_name(sheet)  # 打开每一张表
        row_num = sh.nrows
        print(row_num)
        list = []  # 定义列表用来存放数据
        num = 0  # 用来控制每次插入的数量
        for i in range(1, row_num):  # 第一行是标题名，对应表中的字段名所以应该从第二行开始，计算机以0开始计数，所以值是1
            row_data = sh.row_values(i)  # 按行获取excel的值
            value = (row_data[0], row_data[1], row_data[2])
            list.append(value)  # 将数据暂存在列表
            print(list)
            num += 1
            if( num>= 10000 ):  # 每一万条数据执行一次插入
                print(sys.getsizeof(list))
                sql = "INSERT INTO " + table_name + " (name, num, text)\
                VALUES(%s,%s,%s)"
#                 print(sql)
                cursor.executemany(sql, list)  # 执行sql语句
 
                num = 0  # 计数归零
                list.clear()  # 清空list
                print("worksheets: " + sheet + " has been inserted 10000 datas!")
            else:
                print(sys.getsizeof(list))
                sql = "INSERT INTO " + table_name + " (name, num, text)\
                VALUES(%s,%s,%s)"
#                 print(sql)
                cursor.executemany(sql, list)  # 执行sql语句
#                 print("worksheets: " + sheet + " has been inserted"+ str(num) +"datas!")
                num = 0  # 计数归零
                list.clear()  # 清空list
                
    print("worksheets: " + sheet + " has been inserted " + str(row_num) + " datas!")
    db.commit()  # 提交
    cursor.close()  # 关闭连接
    db.close()
 
if __name__ == '__main__':
    store_to('whgtest', 'test_mysql2', 'test.xlsx')
# Out:
# 64
# 118
# [('wrewr', 1.0, 'dfdsgd')]
# 104
# [('werw', 2.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 3.0, 'dfg')]
# 104
# [('wrewr', 4.0, 'dfdsgd')]
# 104
# [('werw', 5.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 6.0, 'dfg')]
# 104
# [('wrewr', 7.0, 'dfdsgd')]
# 104
# [('werw', 8.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 9.0, 'dfg')]
# 104
# [('wrewr', 10.0, 'dfdsgd')]
# 104
# [('werw', 11.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 12.0, 'dfg')]
# 104
# [('wrewr', 13.0, 'dfdsgd')]
# 104
# [('werw', 14.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 15.0, 'dfg')]
# 104
# [('wrewr', 16.0, 'dfdsgd')]
# 104
# [('werw', 17.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 18.0, 'dfg')]
# 104
# [('wrewr', 19.0, 'dfdsgd')]
# 104
# [('werw', 20.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 21.0, 'dfg')]
# 104
# [('wrewr', 22.0, 'dfdsgd')]
# 104
# [('werw', 23.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 24.0, 'dfg')]
# 104
# [('wrewr', 25.0, 'dfdsgd')]
# 104
# [('werw', 26.0, 'dfgdfgdfg')]
# 104
# [('dffgdfg', 27.0, 'dfg')]
# 104
# ...

# %%
#一键导出表到excel表，如果超过104万多后，是否就直接导出成csv格式或txt格式。或者在另外的sheet存储。

# %%
# coding:utf8
import sys
import imp
imp.reload(sys)
# sys.setdefaultencoding('utf8')
#    __author__ = '郭 璞'
#    __date__ = '2016/8/20'
#    __Desc__ = 从数据库中导出数据到excel数据表中

import xlwt
# import MySQLdb
import pymysql

def export(host,user,password,dbname,table_name,outputpath):
#     conn = MySQLdb.connect(host,user,password,dbname,charset='utf8')
    conn = pymysql.connect(host="127.0.0.1", user=user,
                             passwd=password,
                             db=dbname,
                             charset='utf8')
    cursor = conn.cursor()
    count = cursor.execute('select * from '+table_name)
    print(count)
 # 重置游标的位置
    cursor.scroll(0,mode='absolute')
 # 搜取所有结果
    results = cursor.fetchall()

 # 获取MYSQL里面的数据字段名称
    fields = cursor.description
    workbook = xlwt.Workbook()
    sheet = workbook.add_sheet('table_'+table_name,cell_overwrite_ok=True)
 # 写上字段信息
    for field in range(0,len(fields)):
        sheet.write(0,field,fields[field][0])

 # 获取并写入数据段信息
        row = 1
        col = 0
    for row in range(1,len(results)+1):
        for col in range(0,len(fields)):
            sheet.write(row,col,u'%s'%results[row-1][col])

            workbook.save(outputpath)


# 结果测试
if __name__ == "__main__":
    export('localhost','root','','whgtest','test_mysql2',r'test_mysql2.xlsx')
# Out:
# 117

# %%
# %sql mysql+pymysql://ffzs:666666@localhost/test

# %%
# %load_ext sql
# Out:
# The sql module is not an IPython extension.

# %%
# %sql mysql+pymysql://root:whgdev@localhost/whgtest
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %%sql
# select * from
# test_mysql
# Out:
#  * mysql+pymysql://root:***@localhost/whgtest
# 119 rows affected.
# [('Zarten_1', 1, "let's go"),
#  ('Zarten_1', 1, "let's go"),
#  ('wrewr', 1, 'dfdsgd'),
#  ('werw', 2, 'dfgdfgdfg'),
#  ('dffgdfg', 3, 'dfg'),
#  ('wrewr', 4, 'dfdsgd'),
#  ('werw', 5, 'dfgdfgdfg'),
#  ('dffgdfg', 6, 'dfg'),
#  ('wrewr', 7, 'dfdsgd'),
#  ('werw', 8, 'dfgdfgdfg'),
#  ('dffgdfg', 9, 'dfg'),
#  ('wrewr', 10, 'dfdsgd'),
#  ('werw', 11, 'dfgdfgdfg'),
#  ('dffgdfg', 12, 'dfg'),
#  ('wrewr', 13, 'dfdsgd'),
#  ('werw', 14, 'dfgdfgdfg'),
#  ('dffgdfg', 15, 'dfg'),
#  ('wrewr', 16, 'dfdsgd'),
#  ('werw', 17, 'dfgdfgdfg'),
#  ('dffgdfg', 18, 'dfg'),
#  ('wrewr', 19, 'dfdsgd'),
#  ('werw', 20, 'dfgdfgdfg'),
#  ('dffgdfg', 21, 'dfg'),
#  ('wrewr', 22, 'dfdsgd'),
#  ('werw', 23, 'dfgdfgdfg'),
#  ('dffgdfg', 24, 'dfg'),
#  ('wrewr', 25, 'dfdsgd'),
#  ('werw', 26, 'dfgdfgdfg'),
#  ('dffgdfg', 27, 'dfg'),
#  ('wrewr', 28, 'dfdsgd'),
#  ('werw', 29, 'dfgdfgdfg'),
#  ('dffgdfg', 30, 'dfg'),
# ...

# %%
    # %sql select min(pretrade_date) from stock_basic limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/whgtest
# 1 rows affected.
# [('20180831',)]

# %%
# %%sql
# show databases;
# show tables;
# Out:
#  * mysql+pymysql://root:***@localhost/whgtest
# 5 rows affected.
# 21 rows affected.
# [('ATTACHEMENT',),
#  ('Functions',),
#  ('Menus',),
#  ('ORG',),
#  ('ORGTYPE',),
#  ('Role',),
#  ('RoleFunctions',),
#  ('RoleMenus',),
#  ('SELFMANAGE',),
#  ('SELF_ATT',),
#  ('TestIndex',),
#  ('USER',),
#  ('UsRole',),
#  ('WisdomFina',),
#  ('WisdomFina_bak',),
#  ('WisdomFina_bak2',),
#  ('mydf',),
#  ('test_mysql',),
#  ('test_mysql2',),
#  ('test_mysql3',),
#  ('test_mysql4',)]

# %%
# %%sql
# show databases;
# Out:
#  * mysql+pymysql://root:***@localhost/whgtest
# 5 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('whgtest',)]

# %%
# %%sql
# show tables;
# Out:
# UsageError: Cell magic `%%sql` not found.
